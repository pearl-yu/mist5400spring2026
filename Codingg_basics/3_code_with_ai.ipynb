# %% [markdown]
# <a href="https://colab.research.google.com/github/pearl-yu/mist5400spring2026/blob/main/Codingg_basics/3_code_with_ai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Code with AI
#
#
# Spring 2026 - Instructor: Pearl (Peiyan) Yu
#
# ***

# %% [markdown]
# We will start by analyzing a dataset of college enrollments. [Download the dataset](https://drive.google.com/uc?export=download&id=1S80F6kmmSnbk94FcEPPHzKuzA-NLk6hp)
#
#
# We will briefly show how GenAI works within Colab

# %% [markdown]
# It contains a number of variables for 777 different universities and colleges in the US. The variables are:
#
# - Private : Public/private indicator
# - Apps : Number of applications received
# - Accept : Number of applicants accepted
# - Enroll : Number of new students enrolled
# - Top10perc : New students from top 10 % of high school class
# - Top25perc : New students from top 25 % of high school class
# - F. Undergrad : Number of full-time undergraduates
# - P.Undergrad : Number of part-time undergraduates
# - Outstate : Out-of-state tuition
# - Room.Board : Room and board costs
# - Books : Estimated book costs
# - Personal : Estimated personal spending
# - PhD : Percent of faculty with Ph.D.s
# - Terminal : Percent of faculty with terminal degree
# - S.F.Ratio : Student/faculty ratio
# - perc.alumni : Percent of alumni who donate
# - Expend : Instructional expenditure per student
# - Grad.Rate : Graduation rate

# %% [markdown]
# Gemini: It's integrated into Colab.
#
# Can type **at the hashtag** in a code cell.  Or, use the **generate** function.
#
# Github Copilot (free for students) is integrated into VS Code, so that's another option if you want an AI model integrated into your IDE.

# %% [markdown]
# ## Explain code
#
# We could, ask your GenAI model to explain the code / add comments.

# %% [markdown]
# **Exercise**: example prompt: Can you add comments to explain what the packages are for?

# %%
# start by importing packages

import numpy as np
import pandas as pd
import sklearn as sk
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Generate code for easy things
#
# This is recommended for easy things that you know how to do, but just want to save time.

# %% [markdown]
# Let's first upload our local dataset (the College_Data.csv downloaded to your laptop earlier) to our current workspace:
#
# <img src="https://drive.google.com/uc?id=1ITSANaV_7nCA4UCG0BIPZdxDANkO_MV6" width="300">

# %% [markdown]
# Now let's ask Gemini to import this dataset in our Cloud workspace.
#
# **Exercise**: You could use this prompt: import the College_Data.cvs

# %% [markdown]
# Now we'd like to preview what the data looks like.
#
# **Exercise:** Prompt: Display the first few rows of the dataframe to verify

# %% [markdown]
# ## Debug
#
# We can also ask it to debug code, find errors and correct them.
#
# **Exercise**: Run the code below and ask Gemini to explain the error, fix the code.

# %%
# Prompt: debug?
collage.descibe()

# %% [markdown]
# ## Generate code for more stuff

# %% [markdown]
# Manipulate the dataset: Change the column name from Unamed:0 to SchoolName

# %% [markdown]
# Plots: Plot a histogram of Top10Perc

# %% [markdown]
# Other operations: Find the top 10 schools with the best Graduation Rates

# %% [markdown]
# ## In-class Exercise
# Take a look at the data fields, and think of one more thing you'd like to know about college enrollments. Ask Gemini to give you the plots. Are the plots what you expected? Try to ask Gemini to refine it if you don't like parts of it.
#
# After you completed this, save and **download** the notebook and **submit in eLC assignment --> In-class exercise 1.**

# %% [markdown]
# ***[The End]***
